# %% [markdown]
# # Manipulating Images
# From Chapter 19 of 'Automate The Boring Stuff With Python' by Al Sweigart

# %%
#pip install pillow
from PIL import ImageColor
from PIL import Image

# %% [markdown]
# ## Colors and RGBA Values

# %% [markdown]
# In <b>Pillow</b>, RGBA values are represented by a tuple of four integer values. For example, the color red is represented by (255, 0, 0, 255). This color has the maximum amount of red, no green or blue, and the maximum alpha value, meaning it is fully opaque. Green is represented by (0, 255, 0, 255), and blue is (0, 0, 255, 255). White, the combination of all colors, is (255, 255, 255, 255), while black, which has no color at all, is (0, 0, 0, 255).
#
# Pillow uses the standard color names that HTML uses. The next table lists a selection of standard color names and their values.
#
# ![Screen%20Shot%202021-05-05%20at%203.00.39.png](attachment:Screen%20Shot%202021-05-05%20at%203.00.39.png)

# %% [markdown]
# ### ImageColor.getcolor()
# This function takes a color name string as its first argument, and the string 'RGBA' as its second argument, and it returns an RGBA tuple.

# %%
c_red = ImageColor.getcolor('red', 'RGBA')
c_black = ImageColor.getcolor('black', 'RGBA')
c_white = ImageColor.getcolor('white', 'RGBA')
c_choc = ImageColor.getcolor('chocolate', 'RGBA')

print("Red: ", c_red)
print("Black: ", c_black)
print("White: ", c_white)
print("Chocolate: ", c_choc)
# Out:
# Red:  (255, 0, 0, 255)
# Black:  (0, 0, 0, 255)
# White:  (255, 255, 255, 255)
# Chocolate:  (210, 105, 30, 255)

# %% [markdown]
# ---

# %% [markdown]
# ## Manipulating Images with Pillow

# %%
w_logo = Image.open('w_logo.png')
print("Size ", w_logo.size)
print("Filename ", w_logo.filename)
print("Format ", w_logo.format)
print("Format Description ", w_logo.format_description)
# Out:
# Size  (3500, 3516)
# Filename  w_logo.png
# Format  PNG
# Format Description  Portable network graphics

# %%
new_img = Image.new('RGBA', (100,200), 'chocolate')
new_img.save('chocolateImg.png')
new_img2 = Image.new('RGBA', (20,20))
new_img2.save('transparentImg.png')

# %% [markdown]
# ![Screen%20Shot%202021-05-05%20at%2013.11.14.png](attachment:Screen%20Shot%202021-05-05%20at%2013.11.14.png)
